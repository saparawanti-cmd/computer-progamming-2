# %%
import matematika
print(matematika.pi)
# Out:
# 3.142857142857143

# %%
print("Nilai PI:", matematika.pi)
print("luas_lingkaran (r=21):", matematika.luas_lingkaran(radius=21))
print("luas_persegi (s=12):", matematika.luas_persegi(sisi=12))
# Out:
# Nilai PI: 3.142857142857143
# luas_lingkaran (r=21): 1386.0
# luas_persegi (s=12): 144

# %%
from matematika import luas_persegi as lp
from matematika import luas_lingkaran as ll

print("luas_persegi (s=10):", lp(10))
print("luas_lingkaran (r=21):", ll(7))
# Out:
# luas_persegi (s=10): 100
# luas_lingkaran (r=21): 154.0

# %%
from luas.segitiga import luas_segitiga
print("luas_segitiga (alas=10, tinggi=5):", luas_segitiga(10,5))
# Out:
# luas_segitiga (alas=10, tinggi=5): 25.0

# %%
import math
import datetime

waktu_sekarang = datetime.datetime.now()
print("Tanggal dan Waktu Saat Ini :", waktu_sekarang)
print("nilai PI dari modul math:", math.pi)
# Out:
# Tanggal dan Waktu Saat Ini : 2026-04-14 07:51:44.765003
# nilai PI dari modul math: 3.141592653589793
