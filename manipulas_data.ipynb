# %%
template = 'Halo, saya %s dari %s'

print(template %('sekar arum parawanti', 'indonesia'))

asal = 'finlandia'

print(asal.find('finlandia'))

angka = '12345'
print('indeks angka 3:', angka.find('3'))
print('indeks angka 45:', angka.find('45'))
print('indeks angka 35:', angka.find('35'))

template = 'halo, saya {nama} dari {asal}'
template_2 = ' saya suka makan {} dan minum {}'

print(template.format(nama='sekar arum parawanti', asal='Indonesia'))
print(template_2.format('Nasi Goreng', 'Air Putih'))

paragraf = 'aku suka makan dimsum, andai dimsum adalah manusia aku akan menikahinya'
x = paragraf.count('aku')

print(f'kata "aku" muncul sebanyak {x} kali')

ibu_kota = 'jakarta'

print(ibu_kota.replace('a', 'i'))
print(ibu_kota.replace('kar', ''))
print(ibu_kota.replace('a',  ''))

print('indonesia adalah negara kepulauan'.swapcase())
print('aKu cInta Negeriku'.swapcase())

template = 'Halo, saya {nama} dari {asal}'
template_2 = 'Saya suka makan {} dan minum {}'

print(template.format(nama = 'sekar arum parawanti', asal = 'Indonesia'))

print(' '.join(['aku', 'suka', 'python']))

print("halo selamat pagi".upper())
print("HALO APA KABAR".lower())

alamat ='surabaya, jawa, timur, indonesia'

print(alamat.split())
print(alamat.split(','))
print(alamat.split(', '))

nama= 'sekar arum parawanti'
asal = 'indonesia'
print(f'perkenalan saya {nama} dari {asal}')
# Out:
# Halo, saya sekar arum parawanti dari indonesia
# 0
# indeks angka 3: 2
# indeks angka 45: 3
# indeks angka 35: -1
# halo, saya sekar arum parawanti dari Indonesia
#  saya suka makan Nasi Goreng dan minum Air Putih
# kata "aku" muncul sebanyak 2 kali
# jikirti
# jata
# jkrt
# INDONESIA ADALAH NEGARA KEPULAUAN
# AkU CiNTA nEGERIKU
# Halo, saya sekar arum parawanti dari Indonesia
# aku suka python
# HALO SELAMAT PAGI
# halo apa kabar
# ['surabaya,', 'jawa,', 'timur,', 'indonesia']
# ['surabaya', ' jawa', ' timur', ' indonesia']
# ['surabaya', 'jawa', 'timur', 'indonesia']
# perkenalan saya sekar arum parawanti dari indonesia
