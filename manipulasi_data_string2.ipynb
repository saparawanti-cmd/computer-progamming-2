# %%
# nama: sekar arum parawanti
# npm: 2411012023

# STRING operations

nama = 'sekar arum parawanti'
asal ="indonesia"

print(nama)

print(asal)

print(nama + asal)

print("halo, nama saya",nama, "asal saya dari", asal)

data_lengkap = nama + asal

print(data_lengkap)

# STRING + NON STRING operations

asal_kota = "Bandar Lampung"
kode_pos = 35140

asal_kota_kode_pos = asal_kota + str(kode_pos)

print(asal_kota_kode_pos)

asal_kota_x3 = asal_kota * 3

print(asal_kota_x3)
# Out:
# sekar arum parawanti
# indonesia
# sekar arum parawantiindonesia
# halo, nama saya sekar arum parawanti asal saya dari indonesia
# sekar arum parawantiindonesia
# Bandar Lampung35140
# Bandar LampungBandar LampungBandar Lampung
